# %% [markdown]
# <a href="https://colab.research.google.com/github/rcarasek/Python-for-Investment/blob/main/etf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U plotly

# %%
# !pip install -q investpy

# %%
import investpy as inv

# %%
import pandas as pd


import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %%
inv.get_etfs_list()
# Out:
# ['Australian High Interest Cash',
#  'VanEck Vectors MSCI International Sustainable Equi',
#  'BetaShares Australian Equities Strong Bear Hedge',
#  'BetaShares Gold Bullion',
#  'Vanguard Australian Shares',
#  'Betashares Active Australian Hybrids',
#  'Montgomery Global Equities Fund',
#  'iShares S&P/ASX Dividend Opportunities',
#  'VanEck Vectors FTSE Global Infrastructure',
#  'WCM Quality Global Growth',
#  'Vanguard Australian Government Bond',
#  'Betashares U.S. Equities Strong Bear Currency Hedg',
#  'Ishares Core S&P/Asx 200',
#  'ANZ SP ASX 300 High Yield Plus',
#  'BetaShares Australian Top 20 Equity Yield Maximise',
#  'VanEck Vectors Australian Equal Weight',
#  'VanEck Vectors MSCI World ex Australia Quality Hed',
#  'Vanguard Australian Property Securities',
#  'Magellan Global Equities',
#  'Perth Mint Gold',
#  'Vanguard Australian Shares High Yield',
#  'BetaShares Legg Mason Real Income',
#  'ETFS Physical Gold',
#  'Vanguard Australian Fixed Interest',
# ...
